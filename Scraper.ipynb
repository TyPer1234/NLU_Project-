# %%
import requests
from bs4 import BeautifulSoup
import os
import re
import csv
from datetime import datetime
import time
import random

# Constants
URL = "https://www.presidency.ucsb.edu/documents/presidential-documents-archive-guidebook/presidential-campaigns-debates-and-endorsements-0"
SAVE_DIR = "debate_data"
CSV_FILE = os.path.join(SAVE_DIR, "vp_primary_debates_by_statement.csv")

# Create output directory
os.makedirs(SAVE_DIR, exist_ok=True)

def fetch_debate_links():
    """Fetch VP and primary debate transcript links from the UCSB website."""
    try:
        response = requests.get(URL)
        response.raise_for_status()
        soup = BeautifulSoup(response.content, "html.parser")
    except requests.RequestException as e:
        print(f"Error fetching URL: {e}")
        return {}

    link_dict = {}

    for link in soup.find_all('tr'):
        date_td = link.find('td', style=lambda x: x and "width:112pt" in x)
        if not date_td:
            continue

        debate_date = date_td.get_text(strip=True)
        if len(debate_date) > 30:
            continue

        name_td = date_td.find_next("td")
        if not name_td:
            continue

        debate_name = name_td.get_text(strip=True)

        # Filter for VP and primary debates only
        is_vp = "Vice" in debate_name
        is_primary = any(word in debate_name for word in ["Republican", "Democratic"]) and "Presidential" not in debate_name

        if not (is_vp or is_primary) or any(word in debate_name.lower() for word in ['cancelled']):
            continue

        link_tag = name_td.find("a")
        hyperlink = link_tag.get("href", None)
        if not hyperlink:
            continue

        # Extract year from the date
        try:
            date_obj = datetime.strptime(debate_date, "%B %d, %Y")
            year = date_obj.year
        except ValueError:
            print(f"Skipping debate with invalid date: {debate_date}")
            continue

        # Create a unique ID for the debate
        if is_vp:
            debate_type = "VP"
        elif "Republican" in debate_name:
            debate_type = "Republican"
        elif "Democratic" in debate_name:
            debate_type = "Democratic"
        else:
            debate_type = "Other"

        debate_id = f"{year}_{debate_type}_{date_obj.strftime('%m%d')}"

        link_dict[debate_name] = {
            'date': debate_date,
            'url': hyperlink,
            'year': year,
            'debate_id': debate_id,
            'party': debate_type if debate_type != "VP" else "VP",
            'type': "Primary" if debate_type in ["Republican", "Democratic"] else "VP"
        }

    return link_dict

def parse_debate_transcript(soup, debate_info):
    """Parse the debate transcript into statements with speaker information."""
    content_div = soup.find("div", class_="field-docs-content")
    if not content_div:
        return []

    paragraphs = content_div.find_all("p")
    statements = []

    current_speaker = "MODERATOR"  # Default speaker
    for p in paragraphs:
        text = p.get_text(strip=True)
        if not text:
            continue

        # Try to identify speaker patterns
        # Common patterns: "SPEAKER:", "SPEAKER."
        speaker_match = re.match(r'^([A-Z][A-Z\s\.\-\']+)(?::|\.)\s*(.*)', text)

        if speaker_match:
            speaker = speaker_match.group(1).strip()
            statement_text = speaker_match.group(2).strip()

            # If we only have a speaker with no statement, skip it
            if not statement_text:
                current_speaker = speaker
                continue

            statements.append({
                'speaker': speaker,
                'statement': statement_text,
                'debate_id': debate_info['debate_id'],
                'year': debate_info['year'],
                'party': debate_info['party']
            })
            current_speaker = speaker
        else:
            # Some debate formats don't specify the speaker for each paragraph
            if len(text) > 10:  # Avoid very short fragments
                statements.append({
                    'speaker': current_speaker,
                    'statement': text,
                    'debate_id': debate_info['debate_id'],
                    'year': debate_info['year'],
                    'party': debate_info['party']
                })

    return statements

def extract_participants(soup):
    """Try to extract debate participants from the transcript header."""
    participants = []
    content_div = soup.find("div", class_="field-docs-content")

    if content_div:
        # Look for participant lists at the beginning
        first_paragraphs = content_div.find_all("p")[:5]  # Check first few paragraphs
        for p in first_paragraphs:
            text = p.get_text(strip=True)
            if "PARTICIPANTS" in text.upper():
                participant_section = text.split(":", 1)[1] if ":" in text else text
                # Extract names (this is a simplistic approach)
                names = re.findall(r'([A-Z][a-z]+(?:\s+[A-Z][a-z]+){1,3})', participant_section)
                participants.extend(names)

    return participants

def scrape_and_save_to_csv(link_dict):
    """Scrape debate transcripts and save statements to CSV file."""
    # Create or overwrite the CSV file with headers
    with open(CSV_FILE, 'w', newline='', encoding='utf-8') as csvfile:
        fieldnames = ['speaker', 'statement', 'party', 'debate_id', 'year']
        writer = csv.DictWriter(csvfile, fieldnames=fieldnames)
        writer.writeheader()

    total_statements = 0

    for title, debate_info in link_dict.items():
        print(f"Processing: {title} ({debate_info['date']})")

        try:
            response = requests.get(debate_info['url'])
            response.raise_for_status()
            soup = BeautifulSoup(response.content, "html.parser")
        except requests.RequestException as e:
            print(f"Error fetching transcript: {e}")
            continue

        # Extract statements from the transcript
        statements = parse_debate_transcript(soup, debate_info)

        # Save statements to CSV
        with open(CSV_FILE, 'a', newline='', encoding='utf-8') as csvfile:
            writer = csv.DictWriter(csvfile, fieldnames=['speaker', 'statement', 'party', 'debate_id', 'year'])
            for statement in statements:
                writer.writerow(statement)

        debate_statements = len(statements)
        total_statements += debate_statements
        print(f"Added {debate_statements} statements from debate: {title}")

        # Add a delay to avoid overloading the server
        time.sleep(random.uniform(1, 3))

    print(f"Scraping complete. Total statements: {total_statements}")
    print(f"CSV file saved to: {CSV_FILE}")

def main():
    """Main function to execute the script."""
    print("Fetching VP and primary debate links...")
    debate_links = fetch_debate_links()

    if not debate_links:
        print("No relevant debate links found. Exiting...")
        return

    print(f"Found {len(debate_links)} VP and primary debates. Scraping transcripts...")
    scrape_and_save_to_csv(debate_links)

if __name__ == "__main__":
    main()
# Out:
# Fetching VP and primary debate links...
# Found 96 VP and primary debates. Scraping transcripts...
# Processing: Vice Presidential Debate in New York City (October 1, 2024)
# Added 184 statements from debate: Vice Presidential Debate in New York City
# Processing: Republican Candidates Debate in Des Moines, Iowa (December 10, 2011)
# Added 346 statements from debate: Republican Candidates Debate in Des Moines, Iowa
# Processing: Republican Candidates Debate in Tuscaloosa, Alabama (December 6, 2023)
# Added 423 statements from debate: Republican Candidates Debate in Tuscaloosa, Alabama
# Processing: Republican Candidates Debate in Miami, Florida (December 9, 2007)
# Added 469 statements from debate: Republican Candidates Debate in Miami, Florida
# Processing: Republican Candidates Debate in Simi Valley, California (May 3, 2007)
# Added 768 statements from debate: Republican Candidates Debate in Simi Valley, California
# Processing: Republican Candidates Debate in Milwaukee, Wisconsin (November 10, 2015)
# Added 574 statements from debate: Republican Candidates Debate in Milwaukee, Wisconsin
# Processing: Vice Presidential Debate at the University of Utah in Salt Lake City (October 7, 2020)
# Added 247 statements from debate: Vice Presidential Debate at the University of Utah in Salt Lake City
# Processing: Democratic Candidates Debate in Washington, DC (March 15, 2020)
# Added 579 statements from debate: Democratic Candidates Debate in Washington, DC
# Processing: Democratic Candidates Debate in Charleston, South Carolina (July 23, 2007)
# Added 788 statements from debate: Democratic Candidates Debate in Charleston, South Carolina
# Processing: Democratic Candidates Debate in Las Vegas, Nevada (November 15, 2007)
# Added 665 statements from debate: Democratic Candidates Debate in Las Vegas, Nevada
# Processing: Democratic Candidates Debate in Manchester, New Hampshire (January 26, 2000)
# Added 315 statements from debate: Democratic Candidates Debate in Manchester, New Hampshire
# Processing: Democratic Candidates Debate in Des Moines, Iowa (January 8, 2000)
# Added 253 statements from debate: Democratic Candidates Debate in Des Moines, Iowa
# Processing: Democratic Candidates Debate in Los Angeles, California (March 1, 2000)
# Added 298 statements from debate: Democratic Candidates Debate in Los Angeles, California
# Processing: Democratic Candidates Debate in Atlanta, Georgia (November 20, 2019)
# Added 568 statements from debate: Democratic Candidates Debate in Atlanta, Georgia
# Processing: Democratic Candidates Debate in Westerville, Ohio (October 15, 2019)
# Added 900 statements from debate: Democratic Candidates Debate in Westerville, Ohio
# Processing: Democratic Candidates Debate in Houston, Texas (September 12, 2019)
# Added 720 statements from debate: Democratic Candidates Debate in Houston, Texas
# Processing: Democratic Candidates Debate in Detroit, Michigan: Group 2 (July 31, 2019)
# Added 852 statements from debate: Democratic Candidates Debate in Detroit, Michigan: Group 2
# Processing: Democratic Candidates Debate in Detroit, Michigan: Group 1 (July 30, 2019)
# Added 905 statements from debate: Democratic Candidates Debate in Detroit, Michigan: Group 1
# Processing: Democratic Candidates Debate in Miami, Florida: Group 2 (June 27, 2019)
# Added 697 statements from debate: Democratic Candidates Debate in Miami, Florida: Group 2
# Processing: Democratic Candidates Debate in Miami, Florida: Group 1 (June 26, 2019)
# Added 545 statements from debate: Democratic Candidates Debate in Miami, Florida: Group 1
# Processing: Vice Presidential Debate at Longwood University in Farmville, Virginia (October 4, 2016)
# Added 659 statements from debate: Vice Presidential Debate at Longwood University in Farmville, Virginia
# Processing: Democratic Candidates Debate in Brooklyn, New York (April 14, 2016)
# Added 673 statements from debate: Democratic Candidates Debate in Brooklyn, New York
# Processing: Democratic Candidates Debate in Miami, Florida (September 9, 2007)
# Added 325 statements from debate: Democratic Candidates Debate in Miami, Florida
# Processing: Democratic Candidates Debate in Flint, Michigan (March 6, 2016)
# Added 501 statements from debate: Democratic Candidates Debate in Flint, Michigan
# Processing: Democratic Candidates Debate in Milwaukee, Wisconsin (February 11, 2016)
# Added 157 statements from debate: Democratic Candidates Debate in Milwaukee, Wisconsin
# Processing: Democratic Candidates Debate in Durham, New Hampshire (January 5, 2000)
# Added 207 statements from debate: Democratic Candidates Debate in Durham, New Hampshire
# Processing: Democratic Candidates Forum in Des Moines, Iowa (January 25, 2016)
# Added 632 statements from debate: Democratic Candidates Forum in Des Moines, Iowa
# Processing: Republican Candidates Debate in Detroit, Michigan (March 3, 2016)
# Added 794 statements from debate: Republican Candidates Debate in Detroit, Michigan
# Processing: Republican Candidates Debate in Houston, Texas (February 25, 2016)
# Added 904 statements from debate: Republican Candidates Debate in Houston, Texas
# Processing: Republican Candidates Debate in Greenville, South Carolina (February 13, 2016)
# Added 634 statements from debate: Republican Candidates Debate in Greenville, South Carolina
# Processing: Republican Candidates Debate in Manchester, New Hampshire (December 2, 1999)
# Added 338 statements from debate: Republican Candidates Debate in Manchester, New Hampshire
# Processing: Republican Candidates Debate in Des Monies, Iowa (December 13, 1999)
# Added 404 statements from debate: Republican Candidates Debate in Des Monies, Iowa
# Processing: Republican Candidates Debate in North Charleston, South Carolina (January 14, 2016)
# Added 628 statements from debate: Republican Candidates Debate in North Charleston, South Carolina
# Processing: Republican Candidates Debate in Las Vegas, Nevada (October 18, 2011)
# Added 620 statements from debate: Republican Candidates Debate in Las Vegas, Nevada
# Processing: Republican Candidates Debate in Boulder, Colorado (October 28, 2015)
# Added 833 statements from debate: Republican Candidates Debate in Boulder, Colorado
# Processing: Republican Candidates Debate in Cleveland, Ohio (August 6, 2015)
# Added 639 statements from debate: Republican Candidates Debate in Cleveland, Ohio
# Processing: Republican Candidates "Undercard" Debate in Des Moines, Iowa (January 28, 2016)
# Added 251 statements from debate: Republican Candidates "Undercard" Debate in Des Moines, Iowa
# Processing: Republican Candidates "Undercard" Debate in North Charleston, South Carolina (January 14, 2016)
# Added 238 statements from debate: Republican Candidates "Undercard" Debate in North Charleston, South Carolina
# Processing: Republican Candidates "Undercard" Debate in Las Vegas, Nevada (December 15, 2015)
# Added 405 statements from debate: Republican Candidates "Undercard" Debate in Las Vegas, Nevada
# Processing: Republican Candidates "Undercard" Debate in Milwaukee, Wisconsin (November 10, 2015)
# Added 360 statements from debate: Republican Candidates "Undercard" Debate in Milwaukee, Wisconsin
# Processing: Republican Candidates "Undercard" Debate in Boulder, Colorado (October 28, 2015)
# Added 442 statements from debate: Republican Candidates "Undercard" Debate in Boulder, Colorado
# Processing: Republican Candidates "Undercard" Debate in Simi Valley, California (September 16, 2015)
# Added 622 statements from debate: Republican Candidates "Undercard" Debate in Simi Valley, California
# Processing: Republican Candidates "Undercard" Debate in Cleveland, Ohio (August 6, 2015)
# Added 366 statements from debate: Republican Candidates "Undercard" Debate in Cleveland, Ohio
# Processing: Vice Presidential Debate at Centre College in Danville, Kentucky (October 11, 2012)
# Added 606 statements from debate: Vice Presidential Debate at Centre College in Danville, Kentucky
# Processing: Republican Candidates Debate in Mesa, Arizona (February 22, 2012)
# Added 458 statements from debate: Republican Candidates Debate in Mesa, Arizona
# Processing: Republican Candidates Debate in Jacksonville, Florida (January 26, 2012)
# Added 511 statements from debate: Republican Candidates Debate in Jacksonville, Florida
# Processing: Republican Candidates Debate in Tampa, Florida (September 12, 2011)
# Added 481 statements from debate: Republican Candidates Debate in Tampa, Florida
# Processing: Republican Candidates Debate in Charleston, South Carolina (January 19, 2012)
# Added 529 statements from debate: Republican Candidates Debate in Charleston, South Carolina
# Processing: Republican Candidates Debate in Myrtle Beach, South Carolina (January 10, 2008)
# Added 474 statements from debate: Republican Candidates Debate in Myrtle Beach, South Carolina
# Processing: Republican Candidates Debate in Concord, New Hampshire (January 8, 2012)
# Added 377 statements from debate: Republican Candidates Debate in Concord, New Hampshire
# Processing: Republican Candidates Debate in Sioux City, Iowa (December 15, 2011)
# Added 452 statements from debate: Republican Candidates Debate in Sioux City, Iowa
# Processing: Republican Candidates Debate in Washington, DC (November 22, 2011)
# Added 554 statements from debate: Republican Candidates Debate in Washington, DC
# Processing: Republican Candidates Debate in Spartanburg, South Carolina (November 12, 2011)
# Added 324 statements from debate: Republican Candidates Debate in Spartanburg, South Carolina
# Processing: Republican Candidates Debate in Rochester, Michigan (November 9, 2011)
# Added 475 statements from debate: Republican Candidates Debate in Rochester, Michigan
# Processing: Republican Candidates Debate in Hanover, New Hampshire (October 11, 2011)
# Added 572 statements from debate: Republican Candidates Debate in Hanover, New Hampshire
# Processing: Republican Candidates Debate in Orlando, Florida (October 21, 2007)
# Added 481 statements from debate: Republican Candidates Debate in Orlando, Florida
# Processing: Republican Candidates Debate in Ames, Iowa (August 11, 2011)
# Added 584 statements from debate: Republican Candidates Debate in Ames, Iowa
# Processing: Vice Presidential Debate in St. Louis, Missouri (October 2, 2008)
# Added 404 statements from debate: Vice Presidential Debate in St. Louis, Missouri
# Processing: Democratic Candidates Debate in Philadelphia, Pennsylvania (October 30, 2007)
# Added 497 statements from debate: Democratic Candidates Debate in Philadelphia, Pennsylvania
# Processing: Democratic Candidates Debate in Cleveland, Ohio (February 26, 2008)
# Added 349 statements from debate: Democratic Candidates Debate in Cleveland, Ohio
# Processing: Democratic Candidates Debate in Austin, Texas (February 21, 2008)
# Added 301 statements from debate: Democratic Candidates Debate in Austin, Texas
# Processing: Democratic Candidates Debate in Myrtle Beach, South Carolina (January 21, 2008)
# Added 582 statements from debate: Democratic Candidates Debate in Myrtle Beach, South Carolina
# Processing: Democratic Candidates Debate in Johnston, Iowa (December 13, 2007)
# Added 591 statements from debate: Democratic Candidates Debate in Johnston, Iowa
# Processing: Democratic Candidates Radio Debate in Des Monies, Iowa (December 4, 2007)
# Added 710 statements from debate: Democratic Candidates Radio Debate in Des Monies, Iowa
# Processing: Democratic Candidates Debate in Hanover, New Hampshire (September 26, 2007)
# Added 620 statements from debate: Democratic Candidates Debate in Hanover, New Hampshire
# Processing: Democratic Candidates Debate in Des Monies, Iowa (August 19, 2007)
# Added 534 statements from debate: Democratic Candidates Debate in Des Monies, Iowa
# Processing: Democratic Candidates Forum in Chicago, Illinois (August 7, 2007)
# Added 435 statements from debate: Democratic Candidates Forum in Chicago, Illinois
# Processing: Democratic Candidates Forum in Washington, DC (June 28, 2007)
# Added 358 statements from debate: Democratic Candidates Forum in Washington, DC
# Processing: Democratic Candidates Debate in Orangeburg, South Carolina (April 26, 2007)
# Added 583 statements from debate: Democratic Candidates Debate in Orangeburg, South Carolina
# Processing: Republican Candidates Debate in Boca Raton, Florida (January 24, 2008)
# Added 399 statements from debate: Republican Candidates Debate in Boca Raton, Florida
# Processing: Republican Candidates Forum in Milford, New Hampshire (January 6, 2008)
# Added 518 statements from debate: Republican Candidates Forum in Milford, New Hampshire
# Processing: Republican Candidates Debate in Johnston, Iowa (January 15, 2000)
# Added 556 statements from debate: Republican Candidates Debate in Johnston, Iowa
# Processing: Republican Candidates Debate in St. Petersburg, Florida (November 28, 2007)
# Added 843 statements from debate: Republican Candidates Debate in St. Petersburg, Florida
# Processing: Republican Candidates Debate in Dearborn, Michigan (October 9, 2007)
# Added 570 statements from debate: Republican Candidates Debate in Dearborn, Michigan
# Processing: Republican Candidates Forum in Baltimore, Maryland (September 27, 2007)
# Added 450 statements from debate: Republican Candidates Forum in Baltimore, Maryland
# Processing: Republican Candidates Debate in Durham, New Hampshire (January 6, 2000)
# Added 314 statements from debate: Republican Candidates Debate in Durham, New Hampshire
# Processing: Republican Candidates Debate in Columbia, South Carolina (January 7, 2000)
# Added 237 statements from debate: Republican Candidates Debate in Columbia, South Carolina
# Processing: Vice Presidential Debate in Cleveland (October 5, 2004)
# Added 625 statements from debate: Vice Presidential Debate in Cleveland
# Processing: Democratic Candidates Debate in Greenville, South Carolina (January 29, 2004)
# Added 376 statements from debate: Democratic Candidates Debate in Greenville, South Carolina
# Processing: Vice-Presidential Debate at Centre College in Danville, Kentucky (October 5, 2000)
# Added 102 statements from debate: Vice-Presidential Debate at Centre College in Danville, Kentucky
# Processing: Democratic Candidates Debate in New York City (February 21, 2000)
# Added 472 statements from debate: Democratic Candidates Debate in New York City
# Processing: Democratic Candidates Black-Brown Forum in Des Moines, Iowa (January 17, 2000)
# Added 163 statements from debate: Democratic Candidates Black-Brown Forum in Des Moines, Iowa
# Processing: Democratic Candidates Debate on NBC News "Meet the Press" (December 19, 1999)
# Added 359 statements from debate: Democratic Candidates Debate on NBC News "Meet the Press"
# Processing: Democratic Candidates Town Hall in Nashua, New Hampshire (December 17, 1999)
# Added 379 statements from debate: Democratic Candidates Town Hall in Nashua, New Hampshire
# Processing: Democratic Candidates Town Hall in Hanover, New Hampshire (October 27, 1999)
# Added 292 statements from debate: Democratic Candidates Town Hall in Hanover, New Hampshire
# Processing: Republican Candidates Debate in Los Angeles, California (March 2, 2000)
# Added 270 statements from debate: Republican Candidates Debate in Los Angeles, California
# Processing: Republican Candidates Debate in Grand Rapids, Michigan (January 10, 2000)
# Added 496 statements from debate: Republican Candidates Debate in Grand Rapids, Michigan
# Processing: Republican Candidates Debate in Phoenix, Arizona (December 6, 1999)
# Added 396 statements from debate: Republican Candidates Debate in Phoenix, Arizona
# Processing: Republican Candidates Debate in Tempe, Arizona (November 21, 1999)
# Added 160 statements from debate: Republican Candidates Debate in Tempe, Arizona
# Processing: Republican Candidates Town Hall in Hanover, New Hampshire (October 28, 1999)
# Added 311 statements from debate: Republican Candidates Town Hall in Hanover, New Hampshire
# Processing: Republican Candidates Forum in Durham, New Hampshire (October 22, 1999)
# Added 184 statements from debate: Republican Candidates Forum in Durham, New Hampshire
# Processing: Vice Presidential Debate in St. Petersburg (October 9, 1996)
# Added 112 statements from debate: Vice Presidential Debate in St. Petersburg
# Processing: Vice Presidential Debate in Atlanta (October 13, 1992)
# Added 510 statements from debate: Vice Presidential Debate in Atlanta
# Processing: Vice Presidential Debate in Omaha, Nebraska (October 5, 1988)
# Added 151 statements from debate: Vice Presidential Debate in Omaha, Nebraska
# Processing: Vice Presidential Debate in Philadelphia (October 11, 1984)
# Added 119 statements from debate: Vice Presidential Debate in Philadelphia
# Processing: Vice Presidential Debate in Houston (October 15, 1976)
# Added 75 statements from debate: Vice Presidential Debate in Houston
# Scraping complete. Total statements: 45009
# CSV file saved to: debate_data/vp_primary_debates_by_statement.csv
